# %% [markdown]
# <a href="https://colab.research.google.com/github/DoraLai29/makpython/blob/main/20240329%E7%AD%86%E8%A8%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 20240329筆記

# %% [markdown]
# ##使用Pillow做影像處理

# %% [markdown]
# ###讀取影像(Read an image)

# %%
from PIL import Image

# %%
img = Image.open('images.webp')

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=183x274>

# %% [markdown]
# ##顯示圖片的屬性

# %%
img.size
# Out:
# (183, 274)

# %%
img.mode
# Out:
# 'RGB'

# %%
img.format
# Out:
# 'WEBP'

# %% [markdown]
# ###將彩色圖片轉成單色

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=183x274>

# %% [markdown]
# ###圖形存在

# %%
img.convert('L').save("something.webp")

# %% [markdown]
# ###圖形縮放
#
# * resize
# * thumbnail

# %%
img.resize?

# %%
img.resize((103,150))
# Out:
# <PIL.Image.Image image mode=RGB size=103x150>

# %%
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=183x274>

# %%
img01 = img.copy()

# %%
img01.thumbnail?

# %%
img01.thumbnail((103, 150))

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=100x150>

# %% [markdown]
# ###圖形旋轉
#
# * transpose
# * rotate

# %%
img01
# Out:
# <PIL.Image.Image image mode=RGB size=100x150>

# %%
img01.transpose?

# %%
img01.transpose(Image.Transpose.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=150x100>

# %%
from PIL import Image

# %%
img = Image.open('scary cat.jpeg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>

# %%
img.size
# Out:
# (168, 300)

# %%
img.resize((28, 50))
# Out:
# <PIL.Image.Image image mode=RGB size=28x50>

# %%
cat01 = img.convert('L')

# %%
img.transpose(Image.Transpose.ROTATE_180)
# Out:
# <PIL.Image.Image image mode=RGB size=168x300>

# %%
img.save("the scary cat.jpeg")

# %%
img.rotate?

# %%
img.rotate(45, expand=1, fillcolor="white")
# Out:
# <PIL.Image.Image image mode=RGB size=332x332>

# %%
img02 = img.rotate(45, expand=1, fillcolor="white")

# %%
img02.save("scary cat rotated.jpeg")

# %%
r, g, b =img.split()
Image.merge('RGB',(b, g, r))
# Out:
# <PIL.Image.Image image mode=RGB size=168x300>

# %%
img.size
# Out:
# (168, 300)

# %% [markdown]
# ###才切圖片

# %%
img.crop((31, 30, 150, 180))
# Out:
# <PIL.Image.Image image mode=RGB size=119x150>

# %% [markdown]
# ###

# %%
img02.paste(img02, (50, 0))

# %%
img02
# Out:
# <PIL.Image.Image image mode=RGB size=332x332>
